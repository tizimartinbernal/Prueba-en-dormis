# %% [markdown]
# # Protocolo BB84 — Overview (resumen)
#
# Consigna: modelar y experimentar la distribución de claves cuánticas BB84, evaluando ataques y ruido, y completar la cadena clásica (corrección de errores + amplificación de privacidad) para obtener una clave segura compartida.
#
# ## Qué ofrece
# - Simulación end‑to‑end de BB84 con Qiskit Aer (density_matrix) y semilla reproducible.
# - Ataque de Eve (intercept‑resend) con probabilidad configurable.
# - Ruido configurable: depolarizing, bit/phase flip, phase/amplitude damping, thermal relaxation, y error de lectura (p0→1/p1→0).
# - Sliders interactivos para ajustar parámetros (N, semilla, P(Eve), m, tipo/intensidad de ruido, readout p0→1/p1→0, bloque/rondas/seguridad/target, barrido) y ver en vivo su impacto en QBER, clave cribada y P(det).
# - Métricas clave: QBER, longitud de clave cribada, prob. de detección, causas de discrepancia (Eve/Ruido/Aleatorio).
# - Reconciliación con Cascade (paridades, búsqueda binaria, fugas, errores residuales).
# - Amplificación de privacidad con SHAKE‑256 y parámetro de seguridad/target opcional.
# - Interfaz interactiva en 4 partes (básico → Eve → ruido → pipeline completo).
#
# ## Pipeline
# 1) Preparación/ataque: Alice prepara (Z/X), opcional Eve intercepta y reenvía, Bob mide (Z/X).
# 2) Sifting: se conservan bases coincidentes; se obtienen clave cribada y QBER; estimación P(det) con muestreo m.
# 3) Ruido: aplicación de NoiseModel (compuertas $\{I,X,H\}$) y/o error de lectura según parámetros.
# 4) Reconciliación (Cascade): bloques y paridades; corrección por búsqueda binaria; se contabiliza la fuga.
# 5) Privacidad (SHAKE‑256): se limita longitud utilizable y se deriva clave final segura.
#
# ## Métricas
# - Clave cribada/final, QBER, P(det), fugas y errores residuales.
#
# ## Supuestos
# - Un disparo por bit (shots=1), semilla opcional; modelos de ruido de Qiskit Aer (aprox. de hardware real).

# %%
from pathlib import Path

try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB and Path.cwd().name == "content":
    if not Path("quantum-jam-chirimbolo").exists():
        # !git clone https://github.com/segusantos/quantum-jam-chirimbolo.git
        # !pip install quantum-jam-chirimbolo/
    # %cd quantum-jam-chirimbolo
# Out:
# Cloning into 'quantum-jam-chirimbolo'...
# remote: Enumerating objects: 154, done.
# remote: Counting objects: 100% (154/154), done.
# remote: Compressing objects: 100% (121/121), done.
# remote: Total 154 (delta 79), reused 83 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (154/154), 6.33 MiB | 22.34 MiB/s, done.
# Resolving deltas: 100% (79/79), done.
# Processing ./quantum-jam-chirimbolo
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting qiskit>=2.2.3 (from qiskit[visualization]>=2.2.3->quantum-jam-chirimbolo==0.1.0)
#   Downloading qiskit-2.2.3-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (12 kB)
# Collecting qiskit-ibm-runtime>=0.43.1 (from quantum-jam-chirimbolo==0.1.0)
#   Downloading qiskit_ibm_runtime-0.43.1-py3-none-any.whl.metadata (21 kB)
# Collecting qiskit-aer>=0.17.2 (from quantum-jam-chirimbolo==0.1.0)
#   Downloading qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Collecting rustworkx>=0.15.0 (from qiskit>=2.2.3->qiskit[visualization]>=2.2.3->quantum-jam-chirimbolo==0.1.0)
#   Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: numpy<3,>=1.17 in /usr/local/lib/python3.12/dist-packages (from qiskit>=2.2.3->qiskit[visualization]>=2.2.3->quantum-jam-chirimbolo==0.1.0) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit>=2.2.3->qiskit[visualization]>=2.2.3->quantum-jam-chirimbolo==0.1.0) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=2.2.3->qiskit[visualization]>=2.2.3->quantum-jam-chirimbolo==0.1.0) (0.3.8)
# Collecting stevedore>=3.0.0 (from qiskit>=2.2.3->qiskit[visualization]>=2.2.3->quantum-jam-chirimbolo==0.1.0)
#   Downloading stevedore-5.5.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=2.2.3->qiskit[visualization]>=2.2.3->quantum-jam-chirimbolo==0.1.0) (4.15.0)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer>=0.17.2->quantum-jam-chirimbolo==0.1.0) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer>=0.17.2->quantum-jam-chirimbolo==0.1.0) (2.9.0.post0)
# Requirement already satisfied: requests>=2.19 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime>=0.43.1->quantum-jam-chirimbolo==0.1.0) (2.32.4)
# Collecting requests-ntlm>=1.1.0 (from qiskit-ibm-runtime>=0.43.1->quantum-jam-chirimbolo==0.1.0)
#   Downloading requests_ntlm-1.3.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime>=0.43.1->quantum-jam-chirimbolo==0.1.0) (2.5.0)
# Collecting ibm-platform-services>=0.22.6 (from qiskit-ibm-runtime>=0.43.1->quantum-jam-chirimbolo==0.1.0)
#   Downloading ibm_platform_services-0.71.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: pydantic>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime>=0.43.1->quantum-jam-chirimbolo==0.1.0) (2.11.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime>=0.43.1->quantum-jam-chirimbolo==0.1.0) (25.0)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]>=2.2.3->quantum-jam-chirimbolo==0.1.0) (3.10.0)
# Requirement already satisfied: pydot in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]>=2.2.3->quantum-jam-chirimbolo==0.1.0) (3.0.4)
# Requirement already satisfied: Pillow>=4.2.1 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]>=2.2.3->quantum-jam-chirimbolo==0.1.0) (11.3.0)
# Collecting pylatexenc>=1.4 (from qiskit[visualization]>=2.2.3->quantum-jam-chirimbolo==0.1.0)
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: seaborn>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]>=2.2.3->quantum-jam-chirimbolo==0.1.0) (0.13.2)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]>=2.2.3->quantum-jam-chirimbolo==0.1.0) (1.13.3)
# Collecting ibm_cloud_sdk_core<4.0.0,>=3.24.2 (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime>=0.43.1->quantum-jam-chirimbolo==0.1.0)
#   Downloading ibm_cloud_sdk_core-3.24.2-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[visualization]>=2.2.3->quantum-jam-chirimbolo==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[visualization]>=2.2.3->quantum-jam-chirimbolo==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[visualization]>=2.2.3->quantum-jam-chirimbolo==0.1.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[visualization]>=2.2.3->quantum-jam-chirimbolo==0.1.0) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[visualization]>=2.2.3->quantum-jam-chirimbolo==0.1.0) (3.2.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.0->qiskit-ibm-runtime>=0.43.1->quantum-jam-chirimbolo==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.0->qiskit-ibm-runtime>=0.43.1->quantum-jam-chirimbolo==0.1.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.0->qiskit-ibm-runtime>=0.43.1->quantum-jam-chirimbolo==0.1.0) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit-aer>=0.17.2->quantum-jam-chirimbolo==0.1.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19->qiskit-ibm-runtime>=0.43.1->quantum-jam-chirimbolo==0.1.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19->qiskit-ibm-runtime>=0.43.1->quantum-jam-chirimbolo==0.1.0) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19->qiskit-ibm-runtime>=0.43.1->quantum-jam-chirimbolo==0.1.0) (2025.10.5)
# Requirement already satisfied: cryptography>=1.3 in /usr/local/lib/python3.12/dist-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime>=0.43.1->quantum-jam-chirimbolo==0.1.0) (43.0.3)
# Collecting pyspnego>=0.4.0 (from requests-ntlm>=1.1.0->qiskit-ibm-runtime>=0.43.1->quantum-jam-chirimbolo==0.1.0)
#   Downloading pyspnego-0.12.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from seaborn>=0.9.0->qiskit[visualization]>=2.2.3->quantum-jam-chirimbolo==0.1.0) (2.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.3->qiskit[visualization]>=2.2.3->quantum-jam-chirimbolo==0.1.0) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime>=0.43.1->quantum-jam-chirimbolo==0.1.0) (2.0.0)
# Requirement already satisfied: PyJWT<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.2->ibm-platform-services>=0.22.6->qiskit-ibm-runtime>=0.43.1->quantum-jam-chirimbolo==0.1.0) (2.10.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]>=2.2.3->quantum-jam-chirimbolo==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]>=2.2.3->quantum-jam-chirimbolo==0.1.0) (2025.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime>=0.43.1->quantum-jam-chirimbolo==0.1.0) (2.23)
# Downloading qiskit-2.2.3-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 77.6 MB/s eta 0:00:00
# Downloading qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 92.1 MB/s eta 0:00:00
# Downloading qiskit_ibm_runtime-0.43.1-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 57.4 MB/s eta 0:00:00
# Downloading ibm_platform_services-0.71.0-py3-none-any.whl (377 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.4/377.4 kB 28.1 MB/s eta 0:00:00
# Downloading requests_ntlm-1.3.0-py3-none-any.whl (6.6 kB)
# Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 75.3 MB/s eta 0:00:00
# Downloading stevedore-5.5.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.1 MB/s eta 0:00:00
# Downloading ibm_cloud_sdk_core-3.24.2-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.8/75.8 kB 6.2 MB/s eta 0:00:00
# Downloading pyspnego-0.12.0-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 11.2 MB/s eta 0:00:00
# Building wheels for collected packages: quantum-jam-chirimbolo, pylatexenc
#   Building wheel for quantum-jam-chirimbolo (pyproject.toml) ... done
#   Created wheel for quantum-jam-chirimbolo: filename=quantum_jam_chirimbolo-0.1.0-py3-none-any.whl size=13174 sha256=7c9c8051fc33fa51f955d91edf346b26b87ec166e69cb947140a3b25170d8937
#   Stored in directory: /root/.cache/pip/wheels/2f/7c/0a/e72057590437ecd2ab84fe444bfa969ab2884ef64f05844ffe
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=617fbe84f13ec14582664802cb74907bbc1bca82d66ecbee1701590961a393ea
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built quantum-jam-chirimbolo pylatexenc
# Installing collected packages: pylatexenc, stevedore, rustworkx, qiskit, ibm_cloud_sdk_core, qiskit-aer, pyspnego, ibm-platform-services, requests-ntlm, qiskit-ibm-runtime, quantum-jam-chirimbolo
# Successfully installed ibm-platform-services-0.71.0 ibm_cloud_sdk_core-3.24.2 pylatexenc-2.10 pyspnego-0.12.0 qiskit-2.2.3 qiskit-aer-0.17.2 qiskit-ibm-runtime-0.43.1 quantum-jam-chirimbolo-0.1.0 requests-ntlm-1.3.0 rustworkx-0.17.1 stevedore-5.5.0
# /content/quantum-jam-chirimbolo

# %%
import matplotlib.pyplot as plt
import pandas as pd

from src import setup_part1, setup_part2, setup_part3, setup_part4

plt.style.use("seaborn-v0_8-darkgrid")
pd.options.display.max_rows = 200

# %% [markdown]
# ## Parte 1 — Ejecución básica de BB84
#
# Ajusta el número de bits generados por Alice y observa cómo se producen las coincidencias de bases y la clave cribada compartida.

# %%
setup_part1()
# Out:
# VBox(children=(IntSlider(value=12, description='Bits (N)', max=64, min=4), Output()))

# %% [markdown]
# ## Parte 2 — Ataque de Eve y muestreo de detección
#
# Se incorpora una semilla configurable para reproducir experimentos, además de un ataque de interceptación-resend por parte de Eve. Ajusta la probabilidad de interceptación y la cantidad de bits `m` usados para detección.

# %%
setup_part2()
# Out:
# VBox(children=(HBox(children=(IntSlider(value=24, description='Bits (N)', max=128, min=8, step=2), IntSlider(v…

# %% [markdown]
# ## Parte 3 — Explorando el impacto del ruido en BB84
#
# Esta sección extiende la anterior e introduce canales de ruido configurables mediante `AerSimulator`. Ajusta el tipo de ruido y observa cómo varían el QBER y la probabilidad de detección.

# %%
setup_part3()
# Out:
# VBox(children=(HBox(children=(IntSlider(value=48, description='Bits (N)', max=256, min=16, step=4), IntSlider(…

# %% [markdown]
# ## Parte 4 — Corrección de errores y amplificación de privacidad
#
# Aplicamos el algoritmo Cascade para corregir discrepancias residuales y posteriormente ejecutamos privacidad amplificada con SHAKE-256 truncado.

# %%
setup_part4()
# Out:
# VBox(children=(HBox(children=(IntSlider(value=64, description='Bits (N)', max=256, min=16, step=4), IntSlider(…

# %% [markdown]
# ## Conclusiones y próximos pasos
#
# - Explora valores más altos de `N` para obtener estadísticas más estables.
# - Ajusta `m`, las rondas de Cascade y el parámetro de seguridad para equilibrar detección y longitud final.
# - Conecta el cuaderno a un backend real de IBM Quantum para contrastar con hardware físico.
